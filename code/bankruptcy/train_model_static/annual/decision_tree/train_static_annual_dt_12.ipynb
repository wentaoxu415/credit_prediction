# %%
import sys
sys.path.insert(0, '../../../../')
import pandas as pd 
import numpy as np
import scipy
import readline
import matplotlib
import matplotlib.pyplot as plt
import sklearn
from sklearn.tree import DecisionTreeClassifier
from helpers.ipython_helpers import (
    print_full
)
from helpers.train_model_helpers import (
    make_train_and_test_df,
    train_model_by_grid_search_cv,
    train_model_by_random_search_cv,
    make_time_series_iterable,
    f2_score
)
from IPython.display import display
# %matplotlib inline

# %% [markdown]
# # Read Data

# %%
train_df = pd.read_csv("../../../../../data/bankruptcy/train_test_data/annual/train_df_annual_12.csv")
test_df = pd.read_csv("../../../../../data/bankruptcy/train_test_data/annual/test_df_annual_12.csv")

# %%
X_train, X_test, y_train, y_test = make_train_and_test_df(train_df, test_df)

# %%
estimator_dt = DecisionTreeClassifier()

# %%
ts_iterable = make_time_series_iterable(train_df, 1995)

# %% [markdown]
# # Train Models

# %% [markdown]
# ### A1) Decision Tree - Objective=f1, class_weight=1

# %%
tuned_parameters = {
    'class_weight': [{True: 1}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %% [markdown]
# ### A2) Decision Tree - Objective=f1, class_weight=5

# %%
tuned_parameters = {
    'class_weight': [{True: 5}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
# ...

# %% [markdown]
# ### A3) Decision Tree - Objective=f1, class_weight=10

# %%
tuned_parameters = {
    'class_weight': [{True: 10}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   25.9s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### A4) Decision Tree - Objective=f1, class_weight=25

# %%
tuned_parameters = {
    'class_weight': [{True: 25}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   25.3s
# ...

# %% [markdown]
# ### A5) Decision Tree - Objective=f1, class_weight=50

# %%
tuned_parameters = {
    'class_weight': [{True: 50}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   23.3s
# ...

# %% [markdown]
# ### A6) Decision Tree - Objective=f1, class_weight=100

# %%
tuned_parameters = {
    'class_weight': [{True: 100}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   23.7s
# ...

# %% [markdown]
# ### A7) Decision Tree - Objective=f1, class_weight=250

# %%
tuned_parameters = {
    'class_weight': [{True: 250}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   19.7s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### A8) Decision Tree - Objective=f1, class_weight=500

# %%
tuned_parameters = {
    'class_weight': [{True: 500}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   19.1s
# ...

# %% [markdown]
# ### A9) Decision Tree - Objective=f1, class_weight=1000

# %%
tuned_parameters = {
    'class_weight': [{True: 1000}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   17.7s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### A10) Decision Tree - Objective=f1, class_weight=2000

# %%
tuned_parameters = {
    'class_weight': [{True: 2000}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   19.9s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### A11) Decision Tree - Objective=f1, class_weight=3000

# %%
tuned_parameters = {
    'class_weight': [{True: 3000}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   19.8s
# ...

# %% [markdown]
# ### A12) Decision Tree - Objective=f1, class_weight=balanced

# %%
tuned_parameters = {
    'class_weight': ['balanced'],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
scores = ['f1']
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   17.5s
# ...

# %% [markdown]
# ### B1) Decision Tree - Objective=f2, class_weight=1

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 1}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %% [markdown]
# ### B2) Decision Tree - Objective=f2, class_weight=5

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 5}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %% [markdown]
# ### B3) Decision Tree - Objective=f2, class_weight=10

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 10}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   21.6s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### B4) Decision Tree - Objective=f2, class_weight=25

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 25}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   25.1s
# ...

# %% [markdown]
# ### B5) Decision Tree - Objective=f2, class_weight=50

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 50}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   25.8s
# ...

# %% [markdown]
# ### B6) Decision Tree - Objective=f2, class_weight=100

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 100}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   19.7s
# ...

# %% [markdown]
# ### B7) Decision Tree - Objective=f2, class_weight=250

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 250}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   20.7s
# ...

# %% [markdown]
# ### B8) Decision Tree - Objective=f2, class_weight=500

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 500}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   18.3s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### B9) Decision Tree - Objective=f2, class_weight=1000

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 1000}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   18.7s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### B10) Decision Tree - Objective=f2, class_weight=2000

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 2000}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   19.7s
# ...

# %% [markdown]
# ### B11) Decision Tree - Objective=f2, class_weight=3000

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': [{True: 3000}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   19.7s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### B12) Decision Tree - Objective=f2, class_weight=balanced

# %%
scores = [f2_score]
tuned_parameters = {
    'class_weight': ['balanced'],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   17.2s
# ...

# %% [markdown]
# ### C1) Decision Tree - Objective=recall, class_weight=1

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 1}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   22.2s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done 198 out of 198 | elapsed:  1.6min finished
# Best parameters set found on development set:
# ()
# ...

# %% [markdown]
# ### C2) Decision Tree - Objective=recall, class_weight=5

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 5}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   20.9s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### C3) Decision Tree - Objective=recall, class_weight=10

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 10}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   20.8s
# ...

# %% [markdown]
# ### C4) Decision Tree - Objective=recall, class_weight=25

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 25}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   21.6s
# ...

# %% [markdown]
# ### C5) Decision Tree - Objective=recall, class_weight=50

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 50}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   20.3s
# ...

# %% [markdown]
# ### C6) Decision Tree - Objective=recall, class_weight=100

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 100}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   20.0s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### C7) Decision Tree - Objective=recall, class_weight=250

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 250}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   17.7s
# ...

# %% [markdown]
# ### C8) Decision Tree - Objective=recall, class_weight=500

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 500}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   18.0s
# ...

# %% [markdown]
# ### C9) Decision Tree - Objective=recall, class_weight=1000

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 1000}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   18.8s
# ...

# %% [markdown]
# ### C10) Decision Tree - Objective=recall, class_weight=2000

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 2000}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   22.0s
# ...

# %% [markdown]
# ### C11) Decision Tree - Objective=recall, class_weight=3000

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': [{True: 3000}],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   18.4s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### C12) Decision Tree - Objective=recall, class_weight=balanced

# %%
scores = ['recall']
tuned_parameters = {
    'class_weight': ['balanced'],
    'criterion': ['gini', 'entropy'], 
    'max_depth': [None, 5, 10],
    'min_samples_leaf': [1, 5, 10],
}
trained_estimator_df = train_model_by_grid_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_dt, 
    tuned_parameters,
    ts_iterable,
    scores
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 18 candidates, totalling 198 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   17.2s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...
