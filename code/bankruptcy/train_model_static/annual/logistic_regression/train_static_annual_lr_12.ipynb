# %%
import sys
sys.path.insert(0, '../../../../')
import pandas as pd 
import numpy as np
import scipy
import readline
import matplotlib
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LogisticRegression 
from helpers.ipython_helpers import (
    print_full
)
from helpers.train_model_helpers import (
    make_train_and_test_df,
    train_model_by_grid_search_cv,
    train_model_by_random_search_cv,
    make_time_series_iterable,
    f2_score
)
from IPython.display import display
# %matplotlib inline

# %%
train_df = pd.read_csv("../../../../../data/bankruptcy/train_test_data/annual/train_df_annual_12.csv")
test_df = pd.read_csv("../../../../../data/bankruptcy/train_test_data/annual/test_df_annual_12.csv")

# %%
X_train, X_test, y_train, y_test = make_train_and_test_df(train_df, test_df)

# %%
estimator_lr = LogisticRegression(penalty='l2')

# %%
ts_iterable = make_time_series_iterable(train_df, 1995)

# %% [markdown]
# ### Train Models

# %% [markdown]
# ### A1) Logistic Regression - Objective=f1, class_weight=1

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 1}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %% [markdown]
# ### A2) Logistic Regression - Objective=f1, class_weight=5

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 5}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   30.0s finished
# Best parameters set found on development set:
# ()
# {'C': 51.475105608534875, 'class_weight': {True: 5}}
# ()
# F1 Score
# 0.0
# F2 Score
# 0.0
# Recall Score
# 0.0
# Precision Score
# 0.0
# Detailed classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39255
#        True       0.00      0.00      0.00        40
#
# avg / total       1.00      1.00      1.00     39295
#
# ()
# Confusion Matrix:
# Confusion matrix, without normalization
# [[39255     0]
#  [   40     0]]
# ()
# Roc Curve:
# ()

# %% [markdown]
# ### A3) Logistic Regression - Objective=f1, class_weight=10

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 10}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   30.6s finished
# Best parameters set found on development set:
# ()
# {'C': 89.724395509747865, 'class_weight': {True: 10}}
# ()
# F1 Score
# 0.0
# F2 Score
# 0.0
# Recall Score
# 0.0
# Precision Score
# 0.0
# Detailed classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39255
#        True       0.00      0.00      0.00        40
#
# avg / total       1.00      1.00      1.00     39295
#
# ()
# Confusion Matrix:
# Confusion matrix, without normalization
# [[39255     0]
#  [   40     0]]
# ()
# Roc Curve:
# ()

# %% [markdown]
# ### A4) Logistic Regression - Objective=f1, class_weight=25

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 25}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   12.3s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### A5) Logistic Regression - Objective=f1, class_weight=50

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 50}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.7s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### A6) Logistic Regression - Objective=f1, class_weight=100

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 100}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.1s
# ...

# %% [markdown]
# ### A7) Logistic Regression - Objective=f1, class_weight=250

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 250}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.4s
# ...

# %% [markdown]
# ### A8) Logistic Regression - Objective=f1, class_weight=500

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 500}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.0s
# ...

# %% [markdown]
# ### A9) Logistic Regression - Objective=f1, class_weight=1000

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 1000}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   10.7s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### A10) Logistic Regression - Objective=f1, class_weight=2000

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 2000}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.4s
# ...

# %% [markdown]
# ### A11) Logistic Regression - Objective=f1, class_weight=3000

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 3000}]}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.6s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### A12) Logistic Regression - Objective=f1, class_weight=balanced

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': ['balanced']}
scores_lr = ['f1']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for f1
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    9.7s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### B1) Logistic Regression - Objective=f2, class_weight=1

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 1}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   34.0s finished
# Best parameters set found on development set:
# ()
# {'C': 39.614932255599122, 'class_weight': {True: 1}}
# ()
# F1 Score
# 0.0
# F2 Score
# 0.0
# Recall Score
# 0.0
# Precision Score
# 0.0
# Detailed classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39255
#        True       0.00      0.00      0.00        40
#
# avg / total       1.00      1.00      1.00     39295
#
# ()
# Confusion Matrix:
# Confusion matrix, without normalization
# [[39255     0]
#  [   40     0]]
# ()
# Roc Curve:
# ()

# %% [markdown]
# ### B2) Logistic Regression - Objective=f2, class_weight=5

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 5}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   30.1s finished
# Best parameters set found on development set:
# ()
# {'C': 63.515981040362199, 'class_weight': {True: 5}}
# ()
# F1 Score
# 0.0
# F2 Score
# 0.0
# Recall Score
# 0.0
# Precision Score
# 0.0
# Detailed classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39255
#        True       0.00      0.00      0.00        40
#
# avg / total       1.00      1.00      1.00     39295
#
# ()
# Confusion Matrix:
# Confusion matrix, without normalization
# [[39255     0]
#  [   40     0]]
# ()
# Roc Curve:
# ()

# %% [markdown]
# ### B3) Logistic Regression - Objective=f2, class_weight=10

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 10}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   30.2s finished
# Best parameters set found on development set:
# ()
# {'C': 104.26311577948985, 'class_weight': {True: 10}}
# ()
# F1 Score
# 0.0
# F2 Score
# 0.0
# Recall Score
# 0.0
# Precision Score
# 0.0
# Detailed classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39255
#        True       0.00      0.00      0.00        40
#
# avg / total       1.00      1.00      1.00     39295
#
# ()
# Confusion Matrix:
# Confusion matrix, without normalization
# [[39255     0]
#  [   40     0]]
# ()
# Roc Curve:
# ()

# %% [markdown]
# ### B4) Logistic Regression - Objective=f2, class_weight=25

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 25}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.8s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   30.7s finished
# ...

# %% [markdown]
# ### B5) Logistic Regression - Objective=f2, class_weight=50

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 50}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.1s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### B6) Logistic Regression - Objective=f2, class_weight=100

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 100}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.0s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### B7) Logistic Regression - Objective=f2, class_weight=250

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 250}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### B8) Logistic Regression - Objective=f2, class_weight=500

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 500}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   10.6s
# ...

# %% [markdown]
# ### B9) Logistic Regression - Objective=f2, class_weight=1000

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 1000}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   10.7s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   27.4s finished
# ...

# %% [markdown]
# ### B10) Logistic Regression - Objective=f2, class_weight=2000

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 2000}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   14.2s
# ...

# %% [markdown]
# ### B11) Logistic Regression - Objective=f2, class_weight=3000

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 3000}]}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   12.6s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   33.3s finished
# ...

# %% [markdown]
# ### B12) Logistic Regression - Objective=f2, class_weight=balanced

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': ['balanced']}
scores_lr = [f2_score]
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for make_scorer(fbeta_score, beta=2, pos_label=True, average=binary)
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   12.9s
# ...

# %% [markdown]
# ### C1) Logistic Regression - Objective=recall, class_weight=1

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 1}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   30.5s finished
# Best parameters set found on development set:
# ()
# {'C': 22.294749346328658, 'class_weight': {True: 1}}
# ()
# F1 Score
# 0.0
# F2 Score
# 0.0
# Recall Score
# 0.0
# Precision Score
# 0.0
# Detailed classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39255
#        True       0.00      0.00      0.00        40
#
# avg / total       1.00      1.00      1.00     39295
#
# ()
# Confusion Matrix:
# Confusion matrix, without normalization
# [[39255     0]
#  [   40     0]]
# ()
# Roc Curve:
# ()

# %% [markdown]
# ### C2) Logistic Regression - Objective=recall, class_weight=5

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 5}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   33.6s finished
# Best parameters set found on development set:
# ()
# {'C': 51.7946785777008, 'class_weight': {True: 5}}
# ()
# F1 Score
# 0.0
# F2 Score
# 0.0
# Recall Score
# 0.0
# Precision Score
# 0.0
# Detailed classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39255
#        True       0.00      0.00      0.00        40
#
# avg / total       1.00      1.00      1.00     39295
#
# ()
# Confusion Matrix:
# Confusion matrix, without normalization
# [[39255     0]
#  [   40     0]]
# ()
# Roc Curve:
# ()

# %% [markdown]
# ### C3) Logistic Regression - Objective=recall, class_weight=10

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 10}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   30.8s finished
# Best parameters set found on development set:
# ()
# {'C': 86.653335523507508, 'class_weight': {True: 10}}
# ()
# F1 Score
# 0.0
# F2 Score
# 0.0
# Recall Score
# 0.0
# Precision Score
# 0.0
# Detailed classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     39255
#        True       0.00      0.00      0.00        40
#
# avg / total       1.00      1.00      1.00     39295
#
# ()
# Confusion Matrix:
# Confusion matrix, without normalization
# [[39255     0]
#  [   40     0]]
# ()
# Roc Curve:
# ()

# %% [markdown]
# ### C4) Logistic Regression - Objective=recall, class_weight=25

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 25}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   12.6s
# ...

# %% [markdown]
# ### C5) Logistic Regression - Objective=recall, class_weight=50

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 50}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.2s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   33.7s finished
# Best parameters set found on development set:
# ()
# ...

# %% [markdown]
# ### C6) Logistic Regression - Objective=recall, class_weight=100

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 100}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.3s
# ...

# %% [markdown]
# ### C7) Logistic Regression - Objective=recall, class_weight=250

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 250}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
# ...

# %% [markdown]
# ### C8) Logistic Regression - Objective=recall, class_weight=500

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 500}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   13.1s
# ...

# %% [markdown]
# ### C9) Logistic Regression - Objective=recall, class_weight=1000

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 1000}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   12.4s
# ...

# %% [markdown]
# ### C10) Logistic Regression - Objective=recall, class_weight=2000

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 2000}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   15.0s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# ...

# %% [markdown]
# ### C11) Logistic Regression - Objective=recall, class_weight=3000

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': [{True: 3000}]}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   14.0s
# ...

# %% [markdown]
# ### C12) Logistic Regression - Objective=recall, class_weight=balanced

# %%
tuned_parameters_lr = {'C': scipy.stats.expon(scale=100), 'class_weight': ['balanced']}
scores_lr = ['recall']
trained_estimator_lr = train_model_by_random_search_cv(
    X_train, 
    X_test, 
    y_train, 
    y_test, 
    estimator_lr, 
    tuned_parameters_lr, 
    ts_iterable, 
    num_iter=10,
    scores=scores_lr,
    probability=True
)
# Out:
# Tuning hyper-parameters for recall
# ()
# Fitting 11 folds for each of 10 candidates, totalling 110 fits
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.3s
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:   31.4s finished
# Best parameters set found on development set:
# ()
# ...
