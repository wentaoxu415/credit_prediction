# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '../../../../')
from copy import deepcopy
import datetime
from helpers.ipython_helpers import (
    print_full
)
from helpers.rating_model_helpers import (
    RatingModelTrainer,
    run_trainers
)
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# # Read Data

# %%
original_features_df = pd.read_csv("../../../../../data/credit_rating/intermediate_data/transformed_annual_credit_rating_features.csv")

# %%
model = LogisticRegression()
trainer_whole = RatingModelTrainer(original_features_df, model, output_type='is_investment_grade', dev_type='whole')
trainer_delta = RatingModelTrainer(original_features_df, model, output_type='is_investment_grade', dev_type='delta')
trainer_mixed = RatingModelTrainer(original_features_df, model, output_type='is_investment_grade', dev_type='mixed')

# %%
run_trainers([trainer_whole, trainer_delta, trainer_mixed], ["whole", "delta", "mixed"])
# Out:
# ******************************entire test set - whole model******************************
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/wentaoxu/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#           Precision  Recall  F1 Score
# micro        0.7474  0.7474    0.7474
# ...

# %%
model_balanced = LogisticRegression(class_weight='balanced')
trainer_whole_balanced = RatingModelTrainer(original_features_df, model_balanced, output_type='is_investment_grade', dev_type='whole')
trainer_delta_balanced = RatingModelTrainer(original_features_df, model_balanced, output_type='is_investment_grade', dev_type='delta')
trainer_mixed_balanced = RatingModelTrainer(original_features_df, model_balanced, output_type='is_investment_grade', dev_type='mixed')

# %%
run_trainers([trainer_whole_balanced, trainer_delta_balanced, trainer_mixed_balanced], ["whole", "delta", "mixed"])
# Out:
# ******************************entire test set - whole model******************************
#           Precision  Recall  F1 Score
# micro        0.7633  0.7633    0.7633
# macro        0.7920  0.7697    0.7599
# weighted     0.7964  0.7633    0.7587
# Detailed classification report:
#              precision    recall  f1-score   support
#
#       False       0.89      0.62      0.73      5567
#        True       0.69      0.92      0.79      5118
#
# avg / total       0.80      0.76      0.76     10685
#
# Confusion Matrix:
# Confusion matrix, without normalization
#        True   False
# True    4713    405
# False   2124   3443
# ******************************entire test set - delta model******************************
#           Precision  Recall  F1 Score
# micro        0.5252  0.5252    0.5252
# macro        0.5321  0.5303    0.5205
# weighted     0.5333  0.5252    0.5185
# Detailed classification report:
#              precision    recall  f1-score   support
#
# ...
