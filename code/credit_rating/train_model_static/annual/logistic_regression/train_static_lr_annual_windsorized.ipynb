# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sys
sys.path.insert(0, '../../../../')
from copy import deepcopy
import datetime
from helpers.ipython_helpers import (
    print_full
)
from helpers.rating_model_helpers import (
    RatingModelTrainer,
    run_trainers
)
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# # Read Data

# %%
original_features_df = pd.read_csv("../../../../../data/credit_rating/intermediate_data/annual_credit_rating_features.csv")

# %%
model = LogisticRegression()
trainer_whole = RatingModelTrainer(original_features_df, model, output_type='windsorized_ranking', dev_type='whole')
trainer_delta = RatingModelTrainer(original_features_df, model, output_type='windsorized_ranking', dev_type='delta')
trainer_mixed = RatingModelTrainer(original_features_df, model, output_type='windsorized_ranking', dev_type='mixed')

# %%
run_trainers([trainer_whole, trainer_delta, trainer_mixed], ["whole", "delta", "mixed"])
# Out:
# ******************************entire test set - whole model******************************
#           Precision  Recall  F1 Score
# micro        0.1671  0.1671    0.1671
# macro        0.1403  0.1337    0.0798
# weighted     0.1620  0.1671    0.1060
# Detailed classification report:
#              precision    recall  f1-score   support
#
#         1.0       0.02      0.02      0.02        62
#         2.0       0.00      0.00      0.00       103
#         3.0       0.00      0.00      0.00       145
#         4.0       0.00      0.00      0.00       284
#         5.0       0.12      0.79      0.21       523
#         6.0       0.25      0.00      0.00       574
#         7.0       0.05      0.00      0.01       875
#         8.0       0.15      0.31      0.21      1225
#         9.0       0.15      0.01      0.03       934
#        10.0       0.00      0.00      0.00       682
#        11.0       0.18      0.01      0.01       942
# ...

# %%
model_balanced = LogisticRegression(class_weight='balanced')
trainer_whole_balanced = RatingModelTrainer(original_features_df, model_balanced, output_type='windsorized_ranking', dev_type='whole')
trainer_delta_balanced = RatingModelTrainer(original_features_df, model_balanced, output_type='windsorized_ranking', dev_type='delta')
trainer_mixed_balanced = RatingModelTrainer(original_features_df, model_balanced, output_type='windsorized_ranking', dev_type='mixed')

# %%
run_trainers([trainer_whole_balanced, trainer_delta_balanced, trainer_mixed_balanced], ["whole", "delta", "mixed"])
# Out:
# ******************************entire test set - whole model******************************
#           Precision  Recall  F1 Score
# micro        0.1152  0.1152    0.1152
# macro        0.1215  0.1521    0.1013
# weighted     0.1547  0.1152    0.1173
# Detailed classification report:
#              precision    recall  f1-score   support
#
#         1.0       0.02      0.56      0.04        62
#         2.0       0.01      0.16      0.03       103
#         3.0       0.09      0.12      0.10       145
#         4.0       0.00      0.01      0.01       284
#         5.0       0.05      0.05      0.05       523
#         6.0       0.07      0.06      0.06       574
#         7.0       0.07      0.04      0.05       875
#         8.0       0.18      0.15      0.16      1225
#         9.0       0.16      0.04      0.07       934
#        10.0       0.07      0.03      0.04       682
#        11.0       0.11      0.04      0.06       942
# ...
